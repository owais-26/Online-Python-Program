# %%
print("Hellow World");
# Out:
# Hellow World

# %%
a = 5
print a
# Out:
#   File "<ipython-input-2-478e25f3d74c>", line 2
#     print a
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(a)?

# %%
a=5;
b=10;
c=a+b;
print(c)
# Out:
# 15

# %%
x="Owais"
y=" Ansari"
z=x+y
print(z)
# Out:
# Owais Ansari

# %%
f=4;
g=8;
h=f+g;
print(h);
# Out:
# 12

# %%
a="10";
b=20;
c=a+b;
print(c);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-d6591b13bc61> in <module>
#       1 a="10";
#       2 b=20;
# ----> 3 c=a+b;
#       4 print(c);
#
# TypeError: can only concatenate str (not "int") to str

# %%
x=8;
y=x+7;
z=y-x+1;
print(z);
# Out:
# 8

# %%
a=x-5;
y=5
x=1+y
print(x)
# Out:
# 6

# %%
a=12-/4 2*5
print(a)
# Out:
#   File "<ipython-input-23-76f1b1945946>", line 1
#     a=12-/4 2*5
#          ^
# SyntaxError: invalid syntax

# %%
print(a)
# Out:
# 5104.0

# %%
x=10;
y=x%3;
print(y);
# Out:
# 1

# %%
f=10
f=99
print(f)
# Out:
# 99

# %%
g=5
g=g+2
print(g)
# Out:
# 7

# %%
a=3
a+=3
print(a)
# Out:
# 6

# %%
a="Owais Ansari"
print("My Name is "+a)
# Out:
# My Name is Owais Ansari

# %%
gender="female";
if gender=="female":
    print("ALlow krdo saab");
# Out:
# ALlow krdo saab

# %%
gender = "female"
if gender == "Male":
    print("allow for ride");
else:
        print("rok Lo");
# Out:
# rok Lo

# %%
gender = "female"
if gender != "Male":
    print("allow for ride");
else:
        print("rok Lo");
# Out:
# allow for ride

# %%
age = "12";
gender = "male";
if age > "12" or gender == "female":
    Print("Not allowed")
else:
    print ("allowed")
# Out:
# allowed

# %%
marks = "90";
treat = "laiba";
if marks > "91" or treat == "laiba":
    print("i'll give treat");
else:
    print("ponka");
# Out:
# i'll give treat

# %%
marks = "90";
treat = "laiba";
if marks > "91" or treat == "owais":
    print("i'll give treat");
else:
    print("ponka");
# Out:
# ponka

# %%
taha = "TFP";
Ibrahim = "Farhan Biryani";
if taha == "TFP" and Ibrahim != "Farhan Biryani":
    print("Treat Done");
else:
    print("ghar ghar jao");
# Out:
# ghar ghar jao

# %%
percent = 70;
if percent < 100 and percent > 80:
    print("A+ grade");
elif percent < 80 and percent > 70:
    print("A Grade");
elif percent < 70 and percent > 60:
    print("B Grade");
elif percent < 60 and percent > 50:
    print("C Grade");
elif percent < 60 and percent > 50:
    print ("D grade");
else:
    print ("Fail")
# Out:
# A+ grade
