# %%
question1 = input("Who's Your God?  ");
if question1 == "allah":
    print("Muslim");
else:
    print("Non Muslim")
question2 = input("Who's your Prophet?  ");
if question2 == "muhammad PBUH":
    print("Muslim");
else:
    print("Non Muslim");
question3 = input("What is your Deen?  ");
if question3 == "islam":
    print("Muslim");
else:
    print("Non Muslim");
if question1 or question2 or question3 == True :
    print("Decision: Jannat");
else:
    print("Decision:  Jahannum");
# Out:
# Who's Your God?  allah
# Muslim
# Who's your Prophet?  muhammad PBUH
# Muslim
# What is your Deen?  islam
# Muslim
# Decision: Jannat
